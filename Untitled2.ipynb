# %%
import matplotlib.pyplot as plt
# %matplotlib notebook
import matplotlib.patches as mpatches
import numpy as np
import copy

# %%
fig, ax = plt.subplots(figsize=(6, 6))

ellipse = mpatches.Ellipse((3,4), 1, 2, 0,fill=False, edgecolor='red', linewidth=1) 
el2 = copy.copy(ellipse)
print(ellipse.contains_point((3,4)))
ellipse.set_color('green')
ax.add_patch(ellipse)  
ax.set_xlim(5)  
ax.set_ylim(5)
fig.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">
# True

# %%
el2.contains_point((3,4))
# Out:
# True

# %%
ellipse.get_path()
# Out:
# Path(array([[ 0.        , -1.        ],
#        [ 0.2652031 , -1.        ],
#        [ 0.51957987, -0.89463369],
#        [ 0.70710678, -0.70710678],
#        [ 0.89463369, -0.51957987],
#        [ 1.        , -0.2652031 ],
#        [ 1.        ,  0.        ],
#        [ 1.        ,  0.2652031 ],
#        [ 0.89463369,  0.51957987],
#        [ 0.70710678,  0.70710678],
#        [ 0.51957987,  0.89463369],
#        [ 0.2652031 ,  1.        ],
#        [ 0.        ,  1.        ],
#        [-0.2652031 ,  1.        ],
#        [-0.51957987,  0.89463369],
#        [-0.70710678,  0.70710678],
#        [-0.89463369,  0.51957987],
#        [-1.        ,  0.2652031 ],
#        [-1.        ,  0.        ],
#        [-1.        , -0.2652031 ],
#        [-0.89463369, -0.51957987],
#        [-0.70710678, -0.70710678],
#        [-0.51957987, -0.89463369],
#        [-0.2652031 , -1.        ],
#        [ 0.        , -1.        ],
# ...
